# %%
#importing dependencies
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing models
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Importing data and analysing the data

# %%
#loading data into pd dataframe
bcancer_data = pd.read_csv("breast_cancer_data.csv")

# %%
#printing first five datasets
bcancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#total no. of rows and columns
bcancer_data.shape
# Out:
# (569, 33)

# %%
#statistical decription of datasets
bcancer_data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
#information about the datasets
bcancer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
#checking the null values
bcancer_data.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#since the Unnamed column does not have any single data. So we can drop it
bcancer_data.drop("Unnamed: 32", axis=1, inplace=True)

# %%
bcancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
bcancer_data["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ## Analysis

# %%
sns.set()

# %%
plt.figure(figsize=(6,6))
sns.countplot(x="diagnosis", data=bcancer_data)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %%
#encoding the labels as 0--> benign and 1-->malignant
bcancer_data["diagnosis"].replace({"B":0, "M":1}, inplace=True)

# %%
bcancer_data["diagnosis"].value_counts()
# Out:
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
X = bcancer_data.drop("diagnosis", axis=1)
Y = bcancer_data["diagnosis"]

# %%
params = {
        'n_estimators':[10, 20, 50, 100],
        'criterion' :['gini', 'entropy']
    }
gscv = GridSearchCV(RandomForestClassifier(random_state=40), params , cv=5)
gscv.fit(X,Y)

print('Highest score:',  gscv.best_score_,)
print("best_params:", gscv.best_params_)
# Out:
# Highest score: 0.9648967551622419
# best_params: {'criterion': 'entropy', 'n_estimators': 20}

# %%
# params2 = {
#         'C':[1, 5, 10]
#     }
# gscv = GridSearchCV(SVC(kernel='linear'), params2 , cv=5)
# gscv.fit(X,Y)

# print('Highest score:',  gscv.best_score_,)
# print("best_params:", gscv.best_params_)

# %%
params2 = {
    'kernel':['poly', 'rbf', 'sigmoid'],
        'C':[1]
    }
gscv = GridSearchCV(SVC(kernel='poly'), params2 , cv=5)
gscv.fit(X,Y)

print('Highest score:',  gscv.best_score_,)
print("best_params:", gscv.best_params_)
# Out:
# Highest score: 0.6257102934326968
# best_params: {'C': 1, 'kernel': 'sigmoid'}

# %%
# lgscv = GridSearchCV(SVC(kernel='linear'), {'c': [1, 2, 3]} , cv=5)
# gscv.fit(X,Y)

# print('Highest score:',  gscv.best_score_,)
# print("best_params:", gscv.best_params_)

# %%
params3 = {
        'C':[1, 5, 10, 20],
        "penalty":["l1","l2"]
    }
gscv = GridSearchCV(LogisticRegression(), params3 , cv=5)
gscv.fit(X,Y)

print('Highest score:',  gscv.best_score_,)
print("best_params:", gscv.best_params_)
# Out:
# Highest score: 0.5747865238317031
# best_params: {'C': 1, 'penalty': 'l2'}
# C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 20 fits failed out of a total of 40.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1091, in fit
# ...

# %%
models = [LogisticRegression('C': 1, 'penalty': 'l2'), SVC('C': 1, 'kernel': 'sigmoid'), RandomForestClassifier('criterion': 'entropy', 'n_estimators': 20)]
for model in models:
    score = cross_val_score(model, X, Y, cv=5)
    mean = score/len(score)*100
    print('score of', model , ':', score)
    print("Mean score of", model, ':', round(mean, 2))
